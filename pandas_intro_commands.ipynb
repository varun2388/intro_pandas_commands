# %% [markdown]
# <a href="https://colab.research.google.com/github/varun2388/intro_pandas_commands/blob/main/pandas_intro_commands.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('Salaries.csv')

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
#to display first 5 records in the dataset
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
# to display last 5 records in the dataset
df.tail()
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
# name of your columns
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.shape
# Out:
# (78, 6)

# %%
# to find out the datatypes of salaries dataset
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         78 non-null     int64
#  3   service     78 non-null     int64
#  4   sex         78 non-null     object
#  5   salary      78 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 3.8+ KB

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
pd.set_option('display.max_rows',None)

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
# to check for null values
df.isnull().sum()
# Out:
# rank          0
# discipline    0
# phd           0
# service       0
# sex           0
# salary        0
# dtype: int64

# %%
df.describe(include='all')
# Out:
#         rank discipline        phd    service   sex         salary
# count     78         78  78.000000  78.000000    78      78.000000
# unique     3          2        NaN        NaN     2            NaN
# top     Prof          B        NaN        NaN  Male            NaN
# freq      46         42        NaN        NaN    39            NaN
# mean     NaN        NaN  19.705128  15.051282   NaN  108023.782051
# std      NaN        NaN  12.498425  12.139768   NaN   28293.661022
# min      NaN        NaN   1.000000   0.000000   NaN   57800.000000
# 25%      NaN        NaN  10.250000   5.250000   NaN   88612.500000
# 50%      NaN        NaN  18.500000  14.500000   NaN  104671.000000
# 75%      NaN        NaN  27.750000  20.750000   NaN  126774.750000
# max      NaN        NaN  56.000000  51.000000   NaN  186960.000000

# %%
df['rank'].value_counts()
# Out:
# rank
# Prof         46
# AsstProf     19
# AssocProf    13
# Name: count, dtype: int64

# %%
df.mean(numeric_only=True)
# Out:
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %%
# Select only numeric columns for calculating the mean.
numeric_df = df.select_dtypes(include=['number'])
df_mean = numeric_df.mean()
print(df_mean)
# Out:
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %%
df['phd'].mean()
# Out:
# 19.705128205128204

# %%
df['phd'].median()
# Out:
# 18.5

# %%
df['salary'].mean( )
# Out:
# 108023.78205128205

# %%
df['salary'].median()
# Out:
# 104671.0

# %%
df['salary'].mode()
# Out:
# 0    92000
# Name: salary, dtype: int64

# %%
df[['phd','salary']].mean()
# Out:
# phd           19.705128
# salary    108023.782051
# dtype: float64

# %%
df['salary'].var()
# Out:
# 800531254.0427904

# %%
df['salary'].std()
# Out:
# 28293.661022264165

# %%
df['salary'].skew()
# Out:
# 0.45210256755588096

# %%
df['salary'].kurt()
# Out:
# -0.4017126758820546

# %%
df['salary'].max()-df['salary'].min()
# Out:
# 129160

# %%
df['salary'].max()
# Out:
# 186960

# %%
df['salary'].min()
# Out:
# 57800

# %%
df['salary'].count()
# Out:
# 78

# %%
df['rank'].value_counts()
# Out:
# rank
# Prof         46
# AsstProf     19
# AssocProf    13
# Name: count, dtype: int64

# %%
# prompt: can you import basic library pandas in this workbook

import pandas as pd

# %%
# prompt: can you read this file /content/Salaries.csv

import pandas as pd

df = pd.read_csv('/content/Salaries.csv')
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
# prompt: can you use head function and display the first 5 record in the above dataset , dont use any exception handling

import pandas as pd

df = pd.read_csv('/content/Salaries.csv')
print(df.head())
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df.iloc[0:10,0:5]
# Out:
#         rank discipline  phd  service   sex
# 0       Prof          B   56       49  Male
# 1       Prof          A   12        6  Male
# 2       Prof          A   23       20  Male
# 3       Prof          A   40       31  Male
# 4       Prof          B   20       18  Male
# 5       Prof          A   20       20  Male
# 6  AssocProf          A   20       17  Male
# 7       Prof          A   18       18  Male
# 8       Prof          A   29       19  Male
# 9       Prof          A   51       51  Male

# %%
# prompt: select first 10 records and first 5 columns in dataset

import pandas as pd
df = pd.read_csv('/content/Salaries.csv')
df.iloc[0:10,0:5]
# Out:
#         rank discipline  phd  service   sex
# 0       Prof          B   56       49  Male
# 1       Prof          A   12        6  Male
# 2       Prof          A   23       20  Male
# 3       Prof          A   40       31  Male
# 4       Prof          B   20       18  Male
# 5       Prof          A   20       20  Male
# 6  AssocProf          A   20       17  Male
# 7       Prof          A   18       18  Male
# 8       Prof          A   29       19  Male
# 9       Prof          A   51       51  Male

# %%
df.groupby('rank')[['salary','phd']].mean()
# Out:
#                   salary        phd
# rank
# AssocProf   91786.230769  15.076923
# AsstProf    81362.789474   5.052632
# Prof       123624.804348  27.065217

# %%
df.groupby('rank')['salary'].mean()
# Out:
# rank
# AssocProf     91786.230769
# AsstProf      81362.789474
# Prof         123624.804348
# Name: salary, dtype: float64
